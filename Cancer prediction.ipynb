# %%
# Question: Build a classifier to predict car sales and check the accuracy of the prediction.
# given the following dataset
# ---
# Dataset url = https://bit.ly/3dvU2BB

# %%
import pandas as pd
import numpy as np

# %%
car_df= pd.read_csv('https://bit.ly/3dvU2BB')
car_df.head()
# Out:
#   Manufacturer    Model  ...  Latest_Launch  Power_perf_factor
# 0        Acura  Integra  ...       2/2/2012          58.280150
# 1        Acura       TL  ...       6/3/2011          91.370778
# 2        Acura       CL  ...       1/4/2012                NaN
# 3        Acura       RL  ...      3/10/2011          91.389779
# 4         Audi       A4  ...      10/8/2011          62.777639
#
# [5 rows x 16 columns]
